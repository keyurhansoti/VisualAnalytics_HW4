# %%
import nltk , re, string
from nltk import FreqDist
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.stem import *
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
persuation=nltk.corpus.gutenberg.words('austen-persuasion.txt')

# %%
def preparedata(data):
    processed_data = []
    for arrayCount in range(len(data)):
        speaker = re.sub(r'[^a-zA-Z_ ]', '', data[arrayCount])
#         tokens = nltk.word_tokenize(speaker)
        speaker_tokenized = [w.lower() for w in speaker if not re.fullmatch('[' + string.punctuation + ']+', w)]
        processed_data.append([w for w in speaker_tokenized if w not in stopwords.words("english")])
    return processed_data

# %%
def preprocess_data(text):
    preprocess_data = []
    for w in text:
        if(w.isalpha()):
            if not re.fullmatch('[' + string.punctuation + ']+', w):
                preprocess_data.append(w.lower())
    return preprocess_data

# %%
def stem(data, stemtype):
    words = []
    if(stemtype == "porter"):
        stemmer = PorterStemmer()
    elif(stemtype == "snowball"):
        stemmer = SnowballStemmer('english')
    elif (stemtype == "lancaster"):
        stemmer = LancasterStemmer()

    for lines in data:
        words.append(stemmer.stem(lines))
#     print(words)
    return words

# %%
def retwords(words):
    top_words = []
    for i in range(len(words)):
        for wordss in words[i]:
            top_words.append(wordss)
    return top_words

# %%
cleanedPersuation=preprocess_data(persuation)
cleanedPersuation
# Out:
# ['persuasion',
#  'by',
#  'jane',
#  'austen',
#  'chapter',
#  'sir',
#  'walter',
#  'elliot',
#  'of',
#  'kellynch',
#  'hall',
#  'in',
#  'somersetshire',
#  'was',
#  'a',
#  'man',
#  'who',
#  'for',
#  'his',
#  'own',
#  'amusement',
#  'never',
#  'took',
#  'up',
#  'any',
#  'book',
#  'but',
#  'the',
#  'baronetage',
#  'there',
#  'he',
#  'found',
#  'occupation',
#  'for',
#  'an',
#  'idle',
#  'hour',
#  'and',
#  'consolation',
#  'in',
#  'a',
#  'distressed',
#  'one',
#  'there',
#  'his',
#  'faculties',
#  'were',
#  'roused',
#  'into',
#  'admiration',
#  'and',
#  'respect',
#  'by',
#  'contemplating',
#  'the',
#  'limited',
#  'remnant',
#  'of',
#  'the',
#  'earliest',
#  'patents',
#  'there',
#  'any',
#  'unwelcome',
#  'sensations',
#  'arising',
#  'from',
#  'domestic',
#  'affairs',
#  'changed',
#  'naturally',
#  'into',
#  'pity',
#  'and',
#  'contempt',
#  'as',
#  'he',
#  'turned',
#  'over',
#  'the',
#  'almost',
#  'endless',
#  'creations',
#  'of',
#  'the',
#  'last',
#  'century',
#  'and',
#  'there',
#  'if',
#  'every',
#  'other',
#  'leaf',
#  'were',
#  'powerless',
#  'he',
#  'could',
#  'read',
#  'his',
#  'own',
#  'history',
#  'with',
#  'an',
#  'interest',
#  'which',
#  'never',
#  'failed',
#  'this',
#  'was',
#  'the',
#  'page',
#  'at',
#  'which',
#  'the',
#  'favourite',
#  'volume',
#  'always',
#  'opened',
#  'elliot',
#  'of',
#  'kellynch',
#  'hall',
#  'walter',
#  'elliot',
#  'born',
#  'march',
#  'married',
#  'july',
#  'elizabeth',
#  'daughter',
#  'of',
#  'james',
#  'stevenson',
#  'esq',
#  'of',
#  'south',
#  'park',
#  'in',
#  'the',
#  'county',
#  'of',
#  'gloucester',
#  'by',
#  'which',
#  'lady',
#  'who',
#  'died',
#  'he',
#  'has',
#  'issue',
#  'elizabeth',
#  'born',
#  'june',
#  'anne',
#  'born',
#  'august',
#  'a',
#  'still',
#  'born',
#  'son',
#  'november',
#  'mary',
#  'born',
#  'november',
#  'precisely',
#  'such',
#  'had',
#  'the',
#  'paragraph',
#  'originally',
#  'stood',
#  'from',
#  'the',
#  'printer',
#  's',
#  'hands',
#  'but',
#  'sir',
#  'walter',
#  'had',
#  'improved',
#  'it',
#  'by',
#  'adding',
#  'for',
#  'the',
#  'information',
#  'of',
#  'himself',
#  'and',
#  'his',
#  'family',
#  'these',
#  'words',
#  'after',
#  'the',
#  'date',
#  'of',
#  'mary',
#  's',
#  'birth',
#  'married',
#  'december',
#  'charles',
#  'son',
#  'and',
#  'heir',
#  'of',
#  'charles',
#  'musgrove',
#  'esq',
#  'of',
#  'uppercross',
#  'in',
#  'the',
#  'county',
#  'of',
#  'somerset',
#  'and',
#  'by',
#  'inserting',
#  'most',
#  'accurately',
#  'the',
#  'day',
#  'of',
#  'the',
#  'month',
#  'on',
#  'which',
#  'he',
#  'had',
#  'lost',
#  'his',
#  'wife',
#  'then',
#  'followed',
#  'the',
#  'history',
#  'and',
#  'rise',
#  'of',
#  'the',
#  'ancient',
#  'and',
#  'respectable',
#  'family',
#  'in',
#  'the',
#  'usual',
#  'terms',
#  'how',
#  'it',
#  'had',
#  'been',
#  'first',
#  'settled',
#  'in',
#  'cheshire',
#  'how',
#  'mentioned',
#  'in',
#  'dugdale',
#  'serving',
#  'the',
#  'office',
#  'of',
#  'high',
#  'sheriff',
#  'representing',
#  'a',
#  'borough',
#  'in',
#  'three',
#  'successive',
#  'parliaments',
#  'exertions',
#  'of',
#  'loyalty',
#  'and',
#  'dignity',
#  'of',
#  'baronet',
#  'in',
#  'the',
#  'first',
#  'year',
#  'of',
#  'charles',
#  'ii',
#  'with',
#  'all',
#  'the',
#  'marys',
#  'and',
#  'elizabeths',
#  'they',
#  'had',
#  'married',
#  'forming',
#  'altogether',
#  'two',
#  'handsome',
#  'duodecimo',
#  'pages',
#  'and',
#  'concluding',
#  'with',
#  'the',
#  'arms',
#  'and',
#  'motto',
#  'principal',
#  'seat',
#  'kellynch',
#  'hall',
#  'in',
#  'the',
#  'county',
#  'of',
#  'somerset',
#  'and',
#  'sir',
#  'walter',
#  's',
#  'handwriting',
#  'again',
#  'in',
#  'this',
#  'finale',
#  'heir',
#  'presumptive',
#  'william',
#  'walter',
#  'elliot',
#  'esq',
#  'great',
#  'grandson',
#  'of',
#  'the',
#  'second',
#  'sir',
#  'walter',
#  'vanity',
#  'was',
#  'the',
#  'beginning',
#  'and',
#  'the',
#  'end',
#  'of',
#  'sir',
#  'walter',
#  'elliot',
#  's',
#  'character',
#  'vanity',
#  'of',
#  'person',
#  'and',
#  'of',
#  'situation',
#  'he',
#  'had',
#  'been',
#  'remarkably',
#  'handsome',
#  'in',
#  'his',
#  'youth',
#  'and',
#  'at',
#  'fifty',
#  'four',
#  'was',
#  'still',
#  'a',
#  'very',
#  'fine',
#  'man',
#  'few',
#  'women',
#  'could',
#  'think',
#  'more',
#  'of',
#  'their',
#  'personal',
#  'appearance',
#  'than',
#  'he',
#  'did',
#  'nor',
#  'could',
#  'the',
#  'valet',
#  'of',
#  'any',
#  'new',
#  'made',
#  'lord',
#  'be',
#  'more',
#  'delighted',
#  'with',
#  'the',
#  'place',
#  'he',
#  'held',
#  'in',
#  'society',
#  'he',
#  'considered',
#  'the',
#  'blessing',
#  'of',
#  'beauty',
#  'as',
#  'inferior',
#  'only',
#  'to',
#  'the',
#  'blessing',
#  'of',
#  'a',
#  'baronetcy',
#  'and',
#  'the',
#  'sir',
#  'walter',
#  'elliot',
#  'who',
#  'united',
#  'these',
#  'gifts',
#  'was',
#  'the',
#  'constant',
#  'object',
#  'of',
#  'his',
#  'warmest',
#  'respect',
#  'and',
#  'devotion',
#  'his',
#  'good',
#  'looks',
#  'and',
#  'his',
#  'rank',
#  'had',
#  'one',
#  'fair',
#  'claim',
#  'on',
#  'his',
#  'attachment',
#  'since',
#  'to',
#  'them',
#  'he',
#  'must',
#  'have',
#  'owed',
#  'a',
#  'wife',
#  'of',
#  'very',
#  'superior',
#  'character',
#  'to',
#  'any',
#  'thing',
#  'deserved',
#  'by',
#  'his',
#  'own',
#  'lady',
#  'elliot',
#  'had',
#  'been',
#  'an',
#  'excellent',
#  'woman',
#  'sensible',
#  'and',
#  'amiable',
#  'whose',
#  'judgement',
#  'and',
#  'conduct',
#  'if',
#  'they',
#  'might',
#  'be',
#  'pardoned',
#  'the',
#  'youthful',
#  'infatuation',
#  'which',
#  'made',
#  'her',
#  'lady',
#  'elliot',
#  'had',
#  'never',
#  'required',
#  'indulgence',
#  'afterwards',
#  'she',
#  'had',
#  'humoured',
#  'or',
#  'softened',
#  'or',
#  'concealed',
#  'his',
#  'failings',
#  'and',
#  'promoted',
#  'his',
#  'real',
#  'respectability',
#  'for',
#  'seventeen',
#  'years',
#  'and',
#  'though',
#  'not',
#  'the',
#  'very',
#  'happiest',
#  'being',
#  'in',
#  'the',
#  'world',
#  'herself',
#  'had',
#  'found',
#  'enough',
#  'in',
#  'her',
#  'duties',
#  'her',
#  'friends',
#  'and',
#  'her',
#  'children',
#  'to',
#  'attach',
#  'her',
#  'to',
#  'life',
#  'and',
#  'make',
#  'it',
#  'no',
#  'matter',
#  'of',
#  'indifference',
#  'to',
#  'her',
#  'when',
#  'she',
#  'was',
#  'called',
#  'on',
#  'to',
#  'quit',
#  'them',
#  'three',
#  'girls',
#  'the',
#  'two',
#  'eldest',
#  'sixteen',
#  'and',
#  'fourteen',
#  'was',
#  'an',
#  'awful',
#  'legacy',
#  'for',
#  'a',
#  'mother',
#  'to',
#  'bequeath',
#  'an',
#  'awful',
#  'charge',
#  'rather',
#  'to',
#  'confide',
#  'to',
#  'the',
#  'authority',
#  'and',
#  'guidance',
#  'of',
#  'a',
#  'conceited',
#  'silly',
#  'father',
#  'she',
#  'had',
#  'however',
#  'one',
#  'very',
#  'intimate',
#  'friend',
#  'a',
#  'sensible',
#  'deserving',
#  'woman',
#  'who',
#  'had',
#  'been',
#  'brought',
#  'by',
#  'strong',
#  'attachment',
#  'to',
#  'herself',
#  'to',
#  'settle',
#  'close',
#  'by',
#  'her',
#  'in',
#  'the',
#  'village',
#  'of',
#  'kellynch',
#  'and',
#  'on',
#  'her',
#  'kindness',
#  'and',
#  'advice',
#  'lady',
#  'elliot',
#  'mainly',
#  'relied',
#  'for',
#  'the',
#  'best',
#  'help',
#  'and',
#  'maintenance',
#  'of',
#  'the',
#  'good',
#  'principles',
#  'and',
#  'instruction',
#  'which',
#  'she',
#  'had',
#  'been',
#  'anxiously',
#  'giving',
#  'her',
#  'daughters',
#  'this',
#  'friend',
#  'and',
#  'sir',
#  'walter',
#  'did',
#  'not',
#  'marry',
#  'whatever',
#  'might',
#  'have',
#  'been',
#  'anticipated',
#  'on',
#  'that',
#  'head',
#  'by',
#  'their',
#  'acquaintance',
#  'thirteen',
#  'years',
#  'had',
#  'passed',
#  'away',
#  'since',
#  'lady',
#  'elliot',
#  's',
#  'death',
#  'and',
#  'they',
#  'were',
#  'still',
#  'near',
#  'neighbours',
#  'and',
#  'intimate',
#  'friends',
#  'and',
#  'one',
#  'remained',
#  'a',
#  'widower',
#  'the',
#  'other',
#  'a',
#  'widow',
#  'that',
#  'lady',
#  'russell',
#  'of',
#  'steady',
#  'age',
#  'and',
#  'character',
#  'and',
#  'extremely',
#  'well',
#  'provided',
#  'for',
#  'should',
#  'have',
#  'no',
#  'thought',
#  'of',
#  'a',
#  'second',
#  'marriage',
#  'needs',
#  'no',
#  'apology',
#  'to',
#  'the',
#  'public',
#  'which',
#  'is',
#  'rather',
#  'apt',
#  'to',
#  'be',
#  'unreasonably',
#  'discontented',
#  'when',
#  'a',
#  'woman',
#  'does',
#  'marry',
#  'again',
#  'than',
#  'when',
#  'she',
#  'does',
#  'not',
#  'but',
#  'sir',
#  'walter',
#  's',
#  'continuing',
#  'in',
#  'singleness',
#  'requires',
#  'explanation',
#  'be',
#  'it',
#  'known',
#  'then',
#  'that',
#  'sir',
#  'walter',
#  'like',
#  'a',
#  'good',
#  'father',
#  'having',
#  'met',
#  'with',
#  'one',
#  'or',
#  'two',
#  'private',
#  'disappointments',
#  'in',
#  'very',
#  'unreasonable',
#  'applications',
#  'prided',
#  'himself',
#  'on',
#  'remaining',
#  'single',
#  'for',
#  'his',
#  'dear',
#  'daughters',
#  'sake',
#  'for',
#  'one',
#  'daughter',
#  'his',
#  'eldest',
#  'he',
#  'would',
#  'really',
#  'have',
#  'given',
#  'up',
#  'any',
#  'thing',
#  'which',
#  'he',
#  'had',
#  'not',
#  'been',
#  'very',
#  'much',
#  'tempted',
#  'to',
#  'do',
#  'elizabeth',
#  'had',
#  'succeeded',
#  'at',
#  'sixteen',
#  'to',
#  'all',
#  'that',
#  'was',
#  'possible',
#  'of',
#  'her',
#  'mother',
#  's',
#  'rights',
#  'and',
#  'consequence',
#  'and',
#  'being',
#  'very',
#  'handsome',
#  'and',
#  'very',
#  'like',
#  'himself',
#  'her',
#  'influence',
#  'had',
#  'always',
#  'been',
#  'great',
#  'and',
#  'they',
#  'had',
#  'gone',
#  'on',
#  'together',
#  'most',
#  'happily',
#  'his',
#  'two',
#  'other',
#  'children',
#  'were',
#  'of',
#  'very',
#  'inferior',
#  'value',
#  'mary',
#  'had',
#  'acquired',
#  'a',
#  'little',
#  'artificial',
#  'importance',
#  'by',
#  'becoming',
#  'mrs',
#  'charles',
#  'musgrove',
#  'but',
#  'anne',
#  'with',
#  'an',
#  'elegance',
#  'of',
#  'mind',
#  'and',
#  'sweetness',
#  'of',
#  'character',
#  'which',
#  'must',
#  'have',
#  'placed',
#  'her',
#  'high',
#  'with',
#  'any',
#  'people',
#  'of',
#  'real',
#  'understanding',
#  'was',
#  'nobody',
#  'with',
#  'either',
#  'father',
#  'or',
#  'sister',
#  'her',
#  'word',
#  'had',
#  'no',
#  'weight',
#  'her',
#  'convenience',
#  'was',
#  'always',
#  'to',
#  'give',
#  'way',
#  'she',
#  'was',
#  'only',
#  'anne',
#  'to',
#  'lady',
#  'russell',
#  'indeed',
#  'she',
#  'was',
#  'a',
#  'most',
#  'dear',
#  'and',
#  'highly',
#  'valued',
#  'god',
#  'daughter',
#  'favourite',
#  'and',
#  'friend',
#  'lady',
#  'russell',
#  'loved',
#  'them',
#  'all',
#  'but',
#  'it',
#  'was',
#  'only',
#  'in',
#  'anne',
#  'that',
#  'she',
#  'could',
#  'fancy',
#  'the',
#  'mother',
#  'to',
#  'revive',
#  'again',
#  'a',
#  'few',
#  'years',
#  'before',
#  'anne',
#  'elliot',
#  'had',
#  'been',
#  'a',
#  'very',
#  'pretty',
#  'girl',
#  'but',
#  'her',
#  'bloom',
#  'had',
#  'vanished',
#  'early',
#  'and',
#  'as',
#  'even',
#  'in',
#  'its',
#  'height',
#  'her',
#  'father',
#  'had',
#  'found',
#  'little',
#  'to',
#  'admire',
#  'in',
#  'her',
#  'so',
#  'totally',
#  ...]

# %%
persuationStem=stem(cleanedPersuation,'porter')
persuationStem[:10]
# Out:
# ['persuas',
#  'by',
#  'jane',
#  'austen',
#  'chapter',
#  'sir',
#  'walter',
#  'elliot',
#  'of',
#  'kellynch']

# %%
persuationFdist = nltk.FreqDist(persuationStem)

# %%
persuationFdist.most_common()
# Out:
# [('the', 3329),
#  ('to', 2808),
#  ('and', 2801),
#  ('of', 2570),
#  ('a', 1595),
#  ('in', 1389),
#  ('wa', 1337),
#  ('her', 1215),
#  ('had', 1186),
#  ('be', 1171),
#  ('she', 1146),
#  ('i', 1124),
#  ('it', 1110),
#  ('he', 961),
#  ('not', 934),
#  ('that', 882),
#  ('as', 809),
#  ('for', 708),
#  ('have', 681),
#  ('but', 664),
#  ('hi', 659),
#  ('with', 654),
#  ('you', 628),
#  ('mr', 547),
#  ('at', 533),
#  ('all', 530),
#  ('ann', 497),
#  ('been', 496),
#  ('s', 485),
#  ('him', 467),
#  ('could', 451),
#  ('veri', 434),
#  ('they', 433),
#  ('were', 426),
#  ('by', 418),
#  ('which', 416),
#  ('is', 398),
#  ('on', 396),
#  ('so', 359),
#  ('no', 356),
#  ('would', 355),
#  ('captain', 305),
#  ('their', 301),
#  ('elliot', 295),
#  ('from', 295),
#  ('there', 286),
#  ('or', 274),
#  ('more', 273),
#  ('them', 270),
#  ('thi', 250),
#  ('an', 245),
#  ('than', 243),
#  ('ladi', 242),
#  ('one', 240),
#  ('do', 238),
#  ('must', 228),
#  ('when', 228),
#  ('my', 223),
#  ('onli', 219),
#  ('wentworth', 218),
#  ('such', 211),
#  ('much', 205),
#  ('if', 202),
#  ('ani', 199),
#  ('other', 197),
#  ('what', 197),
#  ('good', 191),
#  ('who', 190),
#  ('should', 188),
#  ('me', 188),
#  ('think', 183),
#  ('littl', 177),
#  ('said', 173),
#  ('will', 172),
#  ('musgrov', 171),
#  ('time', 168),
#  ('charl', 166),
#  ('might', 166),
#  ('see', 165),
#  ('own', 164),
#  ('well', 164),
#  ('did', 162),
#  ('herself', 159),
#  ('now', 158),
#  ('look', 157),
#  ('feel', 157),
#  ('never', 155),
#  ('we', 155),
#  ('go', 153),
#  ('sir', 149),
#  ('know', 149),
#  ('russel', 148),
#  ('are', 146),
#  ('walter', 141),
#  ('noth', 140),
#  ('mari', 139),
#  ('your', 137),
#  ('am', 137),
#  ('some', 136),
#  ('man', 134),
#  ('quit', 133),
#  ('again', 132),
#  ('great', 130),
#  ('miss', 129),
#  ('like', 128),
#  ('too', 128),
#  ('even', 127),
#  ('how', 125),
#  ('say', 125),
#  ('most', 123),
#  ('seem', 123),
#  ('soon', 122),
#  ('father', 118),
#  ('though', 117),
#  ('make', 117),
#  ('befor', 116),
#  ('come', 115),
#  ('two', 114),
#  ('first', 113),
#  ('friend', 113),
#  ('louisa', 111),
#  ('alway', 110),
#  ('wish', 109),
#  ('without', 108),
#  ('can', 107),
#  ('place', 105),
#  ('bath', 104),
#  ('thought', 103),
#  ('everi', 102),
#  ('ha', 102),
#  ('day', 101),
#  ('room', 100),
#  ('hous', 100),
#  ('give', 99),
#  ('sister', 99),
#  ('long', 99),
#  ('into', 98),
#  ('admir', 97),
#  ('about', 97),
#  ('after', 96),
#  ('made', 96),
#  ('happi', 96),
#  ('himself', 95),
#  ('out', 95),
#  ('harvil', 93),
#  ('last', 92),
#  ('up', 91),
#  ('elizabeth', 90),
#  ('howev', 89),
#  ('talk', 89),
#  ('famili', 88),
#  ('acquaint', 88),
#  ('may', 87),
#  ('better', 87),
#  ('walk', 86),
#  ('year', 85),
#  ('same', 85),
#  ('mani', 85),
#  ('over', 84),
#  ('way', 84),
#  ('young', 84),
#  ('moment', 84),
#  ('found', 83),
#  ('home', 83),
#  ('hope', 82),
#  ('croft', 82),
#  ('felt', 80),
#  ('take', 79),
#  ('want', 79),
#  ('away', 78),
#  ('ever', 78),
#  ('uppercross', 77),
#  ('sure', 77),
#  ('present', 76),
#  ('manner', 76),
#  ('still', 74),
#  ('done', 74),
#  ('henrietta', 74),
#  ('kellynch', 73),
#  ('use', 73),
#  ('believ', 73),
#  ('those', 72),
#  ('upon', 72),
#  ('enough', 71),
#  ('then', 70),
#  ('back', 70),
#  ('live', 70),
#  ('parti', 70),
#  ('benwick', 70),
#  ('smith', 70),
#  ('mind', 69),
#  ('while', 69),
#  ('off', 69),
#  ('came', 68),
#  ('woman', 67),
#  ('just', 67),
#  ('our', 67),
#  ('lyme', 67),
#  ('love', 66),
#  ('anoth', 66),
#  ('return', 66),
#  ('clay', 66),
#  ('appear', 65),
#  ('thing', 65),
#  ('heard', 65),
#  ('someth', 64),
#  ('call', 63),
#  ('inde', 63),
#  ('here', 63),
#  ('hour', 62),
#  ('few', 62),
#  ('interest', 61),
#  ('down', 61),
#  ('knew', 61),
#  ('almost', 60),
#  ('rather', 60),
#  ('half', 60),
#  ('mean', 60),
#  ('leav', 60),
#  ('pass', 59),
#  ('possibl', 59),
#  ('morn', 59),
#  ('marri', 58),
#  ('eye', 58),
#  ('seen', 58),
#  ('yet', 58),
#  ('dear', 57),
#  ('onc', 57),
#  ('perhap', 57),
#  ('hear', 57),
#  ('shall', 57),
#  ('person', 56),
#  ('gener', 56),
#  ('oh', 56),
#  ('turn', 55),
#  ('word', 55),
#  ('between', 55),
#  ('part', 55),
#  ('visit', 55),
#  ('poor', 55),
#  ('natur', 54),
#  ('togeth', 54),
#  ('spirit', 54),
#  ('right', 53),
#  ('heart', 53),
#  ('these', 52),
#  ('differ', 52),
#  ('name', 52),
#  ('engag', 52),
#  ('ought', 52),
#  ('observ', 52),
#  ('till', 52),
#  ('charact', 51),
#  ('gone', 51),
#  ('saw', 51),
#  ('where', 51),
#  ('get', 51),
#  ('consid', 50),
#  ('understand', 50),
#  ('idea', 50),
#  ('suppos', 50),
#  ('ye', 50),
#  ('life', 49),
#  ('known', 49),
#  ('speak', 49),
#  ('anyth', 49),
#  ('meet', 49),
#  ('answer', 49),
#  ('receiv', 48),
#  ('left', 48),
#  ('side', 48),
#  ('certainli', 48),
#  ('us', 48),
#  ('chang', 47),
#  ('old', 47),
#  ('short', 47),
#  ('cri', 47),
#  ('cousin', 47),
#  ('deal', 46),
#  ('wife', 45),
#  ('sinc', 45),
#  ('near', 45),
#  ('letter', 45),
#  ('hand', 44),
#  ('end', 44),
#  ('best', 44),
#  ('under', 44),
#  ('repli', 44),
#  ('realli', 43),
#  ('consequ', 43),
#  ('ill', 43),
#  ('attent', 43),
#  ('everyth', 43),
#  ('put', 43),
#  ('perfectli', 43),
#  ('circumst', 43),
#  ('each', 43),
#  ('tell', 43),
#  ('hayter', 43),
#  ('object', 42),
#  ('mother', 42),
#  ('doe', 42),
#  ('least', 42),
#  ('next', 42),
#  ('whole', 42),
#  ('cannot', 42),
#  ('suffer', 42),
#  ('pleasur', 42),
#  ('cours', 42),
#  ('account', 42),
#  ('smile', 42),
#  ('three', 41),
#  ('head', 41),
#  ('comfort', 41),
#  ('stay', 41),
#  ('find', 41),
#  ('listen', 41),
#  ('sort', 41),
#  ('nor', 40),
#  ('set', 40),
#  ('both', 40),
#  ('hardli', 40),
#  ('ask', 40),
#  ('open', 39),
#  ('peopl', 39),
#  ('point', 39),
#  ('among', 39),
#  ('respect', 38),
#  ('attach', 38),
#  ('agreeabl', 38),
#  ('oblig', 38),
#  ('kind', 37),
#  ('immedi', 37),
#  ('expect', 37),
#  ('care', 37),
#  ('themselv', 37),
#  ('pain', 37),
#  ('pleas', 37),
#  ('tri', 37),
#  ('surpris', 37),
#  ('compani', 37),
#  ('begin', 36),
#  ('afterward', 36),
#  ('world', 36),
#  ('either', 36),
#  ('week', 36),
#  ('brother', 36),
#  ('subject', 36),
#  ('husband', 36),
#  ('convers', 36),
#  ('children', 35),
#  ('equal', 35),
#  ('countri', 35),
#  ('invit', 35),
#  ('whom', 35),
#  ('doubt', 35),
#  ('attend', 35),
#  ('opinion', 35),
#  ('remain', 34),
#  ('continu', 34),
#  ('often', 34),
#  ('through', 34),
#  ('recollect', 34),
#  ('wait', 34),
#  ('determin', 34),
#  ('minut', 34),
#  ('walli', 34),
#  ('daughter', 33),
#  ('follow', 33),
#  ('settl', 33),
#  ('fine', 33),
#  ('sensibl', 33),
#  ('brought', 33),
#  ('given', 33),
#  ('state', 33),
#  ('glad', 33),
#  ('imagin', 33),
#  ('toward', 33),
#  ('began', 33),
#  ('delight', 32),
#  ('fortun', 32),
#  ('reason', 32),
#  ('far', 32),
#  ('gentleman', 32),
#  ('men', 32),
#  ('assur', 32),
#  ('whether', 32),
#  ('street', 32),
#  ('dalrympl', 32),
#  ('situat', 31),
#  ('allow', 31),
#  ('shepherd', 31),
#  ('spoke', 31),
#  ('wonder', 31),
#  ('myself', 31),
#  ('matter', 30),
#  ('honour', 30),
#  ('less', 30),
#  ('abl', 30),
#  ('went', 30),
#  ('full', 30),
#  ('improv', 29),
#  ('strong', 29),
#  ('marriag', 29),
#  ('pretti', 29),
#  ('gave', 29),
#  ('case', 29),
#  ('decid', 29),
#  ('busi', 29),
#  ('camden', 29),
#  ('hall', 28),
#  ('ad', 28),
#  ('mention', 28),
#  ('claim', 28),
#  ('therefor', 28),
#  ('regard', 28),
#  ('question', 28),
#  ('against', 28),
#  ('complet', 28),
#  ('let', 28),
#  ('reach', 28),
#  ('former', 28),
#  ('probabl', 28),
#  ('carriag', 28),
#  ('bad', 28),
#  ('sit', 28),
#  ('door', 28),
#  ('high', 27),
#  ('met', 27),
#  ('happen', 27),
#  ('els', 27),
#  ('enjoy', 27),
#  ('view', 27),
#  ('advantag', 27),
#  ('late', 27),
#  ('distress', 26),
#  ('month', 26),
#  ('new', 26),
#  ('excel', 26),
#  ('earli', 26),
#  ('face', 26),
#  ('satisfi', 26),
#  ('express', 26),
#  ('longer', 26),
#  ('hint', 26),
#  ('tast', 26),
#  ('desir', 26),
#  ('degre', 26),
#  ('taken', 26),
#  ('becaus', 26),
#  ('bring', 26),
#  ('told', 26),
#  ('forward', 26),
#  ('promis', 26),
#  ('night', 26),
#  ('influenc', 25),
#  ('neither', 25),
#  ('affect', 25),
#  ('readi', 25),
#  ('past', 25),
#  ('arriv', 25),
#  ('child', 25),
#  ('chapter', 24),
#  ('bless', 24),
#  ('girl', 24),
#  ('need', 24),
#  ('valu', 24),
#  ('draw', 24),
#  ('sever', 24),
#  ('worth', 24),
#  ('wors', 24),
#  ('persuad', 24),
#  ('true', 24),
#  ('depend', 24),
#  ('particular', 24),
#  ('except', 24),
#  ('bear', 24),
#  ('morrow', 24),
#  ('dine', 23),
#  ('regret', 23),
#  ('danger', 23),
#  ('favour', 23),
#  ('notic', 23),
#  ('sound', 23),
#  ('agre', 23),
#  ('beyond', 23),
#  ('dare', 23),
#  ('profess', 23),
#  ('sea', 23),
#  ('rememb', 23),
#  ('sight', 23),
#  ('frederick', 23),
#  ('declar', 23),
#  ('cottag', 23),
#  ('colonel', 23),
#  ('amus', 22),
#  ('usual', 22),
#  ('handsom', 22),
#  ('four', 22),
#  ('women', 22),
#  ('real', 22),
#  ('help', 22),
#  ('within', 22),
#  ('admit', 22),
#  ('dispos', 22),
#  ('power', 22),
#  ('knowledg', 22),
#  ('enter', 22),
#  ('dinner', 22),
#  ('play', 22),
#  ('read', 21),
#  ('superior', 21),
#  ('whose', 21),
#  ('fanci', 21),
#  ('rest', 21),
#  ('mere', 21),
#  ('twenti', 21),
#  ('boy', 21),
#  ('match', 21),
#  ('got', 21),
#  ('spoken', 21),
#  ('agit', 21),
#  ('remov', 21),
#  ('anybodi', 21),
#  ('fix', 21),
#  ('arrang', 21),
#  ('particularli', 21),
#  ('fellow', 21),
#  ('air', 21),
#  ('alon', 21),
#  ('fear', 21),
#  ('window', 21),
#  ('join', 21),
#  ('voic', 21),
#  ('recov', 21),
#  ('term', 20),
#  ('form', 20),
#  ('arm', 20),
#  ('conduct', 20),
#  ('becom', 20),
#  ('none', 20),
#  ('health', 20),
#  ('direct', 20),
#  ('dread', 20),
#  ('recommend', 20),
#  ('sens', 20),
#  ('tone', 20),
#  ('understood', 20),
#  ('alreadi', 20),
#  ('sorri', 20),
#  ('perfect', 20),
#  ('astonish', 20),
#  ('assist', 20),
#  ('whi', 20),
#  ('evid', 20),
#  ('nurs', 20),
#  ('concert', 20),
#  ('took', 19),
#  ('exert', 19),
#  ('seat', 19),
#  ('duti', 19),
#  ('indiffer', 19),
#  ('extrem', 19),
#  ('import', 19),
#  ('nobodi', 19),
#  ('larg', 19),
#  ('sometim', 19),
#  ('charm', 19),
#  ('forget', 19),
#  ('self', 19),
#  ('evil', 19),
#  ('acknowledg', 19),
#  ('occupi', 19),
#  ('entir', 19),
#  ('difficulti', 19),
#  ('clear', 19),
#  ('alter', 19),
#  ('style', 19),
#  ('descript', 19),
#  ('concern', 19),
#  ('cheer', 19),
#  ('move', 19),
#  ('book', 18),
#  ('lost', 18),
#  ('pride', 18),
#  ('eleg', 18),
#  ('everybodi', 18),
#  ('money', 18),
#  ('occur', 18),
#  ('small', 18),
#  ('seriou', 18),
#  ('anxiou', 18),
#  ('lodg', 18),
#  ('tenant', 18),
#  ('watch', 18),
#  ('relat', 18),
#  ('also', 18),
#  ('histori', 17),
#  ('son', 17),
#  ('offic', 17),
#  ('second', 17),
#  ('beauti', 17),
#  ('humour', 17),
#  ('common', 17),
#  ('proper', 17),
#  ('sentiment', 17),
#  ('kept', 17),
#  ('civil', 17),
#  ('offer', 17),
#  ('fact', 17),
#  ('servant', 17),
#  ('mile', 17),
#  ('suit', 17),
#  ('warm', 17),
#  ('occas', 17),
#  ('keep', 17),
#  ('curios', 17),
#  ('effect', 17),
#  ('introduc', 17),
#  ('connexion', 17),
#  ('low', 17),
#  ('imposs', 17),
#  ('glanc', 17),
#  ('thank', 17),
#  ('build', 17),
#  ('piti', 16),
#  ('youth', 16),
#  ('requir', 16),
#  ('close', 16),
#  ('excit', 16),
#  ('ago', 16),
#  ('grow', 16),
#  ('increas', 16),
#  ('possess', 16),
#  ('tabl', 16),
#  ('meant', 16),
#  ('period', 16),
#  ('spend', 16),
#  ('vain', 16),
#  ('propos', 16),
#  ('resolut', 16),
#  ('drew', 16),
#  ('proceed', 16),
#  ('inclin', 16),
#  ('judg', 16),
#  ('compar', 16),
#  ('companion', 16),
#  ('safe', 16),
#  ('order', 16),
#  ('caught', 16),
#  ('farther', 16),
#  ('share', 16),
#  ('step', 16),
#  ('quiet', 16),
#  ('impress', 16),
#  ('pleasant', 16),
#  ('eager', 16),
#  ('counten', 16),
#  ('fail', 15),
#  ('deserv', 15),
#  ('confid', 15),
#  ('intim', 15),
#  ('sake', 15),
#  ('highli', 15),
#  ('conscious', 15),
#  ('support', 15),
#  ('futur', 15),
#  ('town', 15),
#  ('instead', 15),
#  ('belong', 15),
#  ('habit', 15),
#  ('consider', 15),
#  ('due', 15),
#  ('convinc', 15),
#  ('act', 15),
#  ('avoid', 15),
#  ('accept', 15),
#  ('behind', 15),
#  ('ventur', 15),
#  ('truth', 15),
#  ('command', 15),
#  ('troubl', 15),
#  ('besid', 15),
#  ('afraid', 15),
#  ('fit', 15),
#  ('necessari', 15),
#  ('proof', 15),
#  ('cold', 15),
#  ('smallest', 15),
#  ('temper', 15),
#  ('chanc', 15),
#  ('prevent', 15),
#  ('produc', 15),
#  ('tender', 15),
#  ('nearli', 15),
#  ('creatur', 15),
#  ('opportun', 15),
#  ('prepar', 15),
#  ('round', 15),
#  ('awar', 15),
#  ('send', 15),
#  ('sick', 15),
#  ('exactli', 15),
#  ('inn', 15),
#  ('card', 15),
#  ('sensat', 14),
#  ('heir', 14),
#  ('remark', 14),
#  ('indulg', 14),
#  ('connect', 14),
#  ('excus', 14),
#  ('neighbourhood', 14),
#  ('london', 14),
#  ('fulli', 14),
#  ('event', 14),
#  ('plan', 14),
#  ('line', 14),
#  ('attempt', 14),
#  ('interv', 14),
#  ('properti', 14),
#  ('justic', 14),
#  ('alarm', 14),
#  ('struck', 14),
#  ('secur', 14),
#  ('hors', 14),
#  ('friendship', 14),
#  ('easi', 14),
#  ('stand', 14),
#  ('servic', 14),
#  ('employ', 14),
#  ('actual', 14),
#  ('distinguish', 14),
#  ('asham', 14),
#  ('convey', 14),
#  ('suspect', 14),
#  ('escap', 14),
#  ('sent', 14),
#  ('yourself', 14),
#  ('stop', 14),
#  ('yesterday', 14),
#  ('enquiri', 14),
#  ('commun', 14),
#  ('sat', 14),
#  ('shew', 14),
#  ('breakfast', 14),
#  ('collect', 14),
#  ('instantli', 14),
#  ('polit', 14),
#  ('reflect', 14),
#  ('cobb', 14),
#  ('write', 14),
#  ('altogeth', 13),
#  ('princip', 13),
#  ('societi', 13),
#  ('rank', 13),
#  ('fair', 13),
#  ('sweet', 13),
#  ('work', 13),
#  ('spring', 13),
#  ('especi', 13),
#  ('appar', 13),
#  ('becam', 13),
#  ('lessen', 13),
#  ('opposit', 13),
#  ('itself', 13),
#  ('carri', 13),
#  ('navi', 13),
#  ('sailor', 13),
#  ('extraordinari', 13),
#  ('greater', 13),
#  ('along', 13),
#  ('sigh', 13),
#  ('intellig', 13),
#  ('learn', 13),
#  ('prove', 13),
#  ('compliment', 13),
#  ('hurri', 13),
#  ('toler', 13),
#  ('strength', 13),
#  ('repeat', 13),
#  ('glow', 13),
#  ('born', 12),
#  ('stood', 12),
#  ('pardon', 12),
#  ('eldest', 12),
#  ('disappoint', 12),
#  ('succeed', 12),
#  ('ten', 12),
#  ('anxieti', 12),
#  ('begun', 12),
#  ('foot', 12),
#  ('credit', 12),
#  ('afford', 12),
#  ('certain', 12),
#  ('rich', 12),
#  ('resid', 12),
#  ('confess', 12),
#  ('hold', 12),
#  ('beg', 12),
#  ('scheme', 12),
#  ('gentl', 12),
#  ('around', 12),
#  ('ground', 12),
#  ('paus', 12),
#  ('weather', 12),
#  ('report', 12),
#  ('suppli', 12),
#  ('silenc', 12),
#  ('suspens', 12),
#  ('divid', 12),
#  ('exceedingli', 12),
#  ('dress', 12),
#  ('truli', 12),
#  ('anim', 12),
#  ('eight', 12),
#  ('directli', 12),
#  ('six', 12),
#  ('board', 12),
#  ('prais', 12),
#  ('five', 12),
#  ('accommod', 12),
#  ('comprehend', 12),
#  ('rain', 12),
#  ('carteret', 12),
#  ('rous', 11),
#  ('domest', 11),
#  ('inform', 11),
#  ('digniti', 11),
#  ('baronet', 11),
#  ('inferior', 11),
#  ('death', 11),
#  ('neighbour', 11),
#  ('widow', 11),
#  ('age', 11),
#  ('public', 11),
#  ('scarc', 11),
#  ('winter', 11),
#  ('rejoic', 11),
#  ('warmth', 11),
#  ('forc', 11),
#  ('ceas', 11),
#  ('summer', 11),
#  ('scene', 11),
#  ('solicitud', 11),
#  ('involv', 11),
#  ('save', 11),
#  ('pay', 11),
#  ('rate', 11),
#  ('prefer', 11),
#  ('satisfact', 11),
#  ('school', 11),
#  ('fond', 11),
#  ('spite', 11),
#  ('shut', 11),
#  ('laugh', 11),
#  ('gentlemen', 11),
#  ('intercours', 11),
#  ('nice', 11),
#  ('refus', 11),
#  ('motiv', 11),
#  ('autumn', 11),
#  ('run', 11),
#  ('confus', 11),
#  ('thousand', 11),
#  ('exclaim', 11),
#  ('instant', 11),
#  ('emot', 11),
#  ('explain', 11),
#  ('written', 11),
#  ('welcom', 11),
#  ('silent', 11),
#  ('ma', 11),
#  ('winthrop', 11),
#  ('shirley', 11),
#  ('hill', 11),
#  ('address', 11),
#  ('birth', 10),
#  ('vaniti', 10),
#  ('constant', 10),
#  ('principl', 10),
#  ('apolog', 10),
#  ('conveni', 10),
#  ('god', 10),
#  ('total', 10),
#  ('featur', 10),
#  ('approach', 10),
#  ('properli', 10),
#  ('consult', 10),
#  ('quick', 10),
#  ('seven', 10),
#  ('sooner', 10),
#  ('materi', 10),
#  ('secret', 10),
#  ('interrupt', 10),
#  ('peac', 10),
#  ('wit', 10),
#  ('suggest', 10),
#  ('pictur', 10),
#  ('hard', 10),
#  ('mine', 10),
#  ('rais', 10),
#  ('nay', 10),
#  ('gratitud', 10),
#  ('gradual', 10),
#  ('wrong', 10),
#  ('miseri', 10),
#  ('whisper', 10),
#  ('cordial', 10),
#  ('burst', 10),
#  ('bow', 10),
#  ('fall', 10),
#  ('catch', 10),
#  ('fashion', 10),
#  ('separ', 10),
#  ('danc', 10),
#  ('stori', 10),
#  ('sincer', 10),
#  ('re', 10),
#  ('shock', 10),
#  ('inconveni', 10),
#  ('renew', 10),
#  ('dr', 10),
#  ('struggl', 10),
#  ('favourit', 9),
#  ('die', 9),
#  ('novemb', 9),
#  ('rise', 9),
#  ('success', 9),
#  ('lord', 9),
#  ('judgement', 9),
#  ('villag', 9),
#  ('steadi', 9),
#  ('applic', 9),
#  ('bloom', 9),
#  ('law', 9),
#  ('travel', 9),
#  ('encourag', 9),
#  ('accomplish', 9),
#  ('drive', 9),
#  ('partial', 9),
#  ('embarrass', 9),
#  ('capabl', 9),
#  ('notion', 9),
#  ('ration', 9),
#  ('calcul', 9),
#  ('submit', 9),
#  ('quarter', 9),
#  ('distanc', 9),
#  ('induc', 9),
#  ('lose', 9),
#  ('intent', 9),
#  ('intimaci', 9),
#  ('selfish', 9),
#  ('war', 9),
#  ('thu', 9),
#  ('heaven', 9),
#  ('bodi', 9),
#  ('fell', 9),
#  ('station', 9),
#  ('contrari', 9),
#  ('ay', 9),
#  ('number', 9),
#  ('intend', 9),
#  ('highest', 9),
#  ('preced', 9),
#  ('attract', 9),
#  ('appli', 9),
#  ('griev', 9),
#  ('stranger', 9),
#  ('ship', 9),
#  ('light', 9),
#  ('delay', 9),
#  ('nerv', 9),
#  ('calm', 9),
#  ('convict', 9),
#  ('absenc', 9),
#  ('warmli', 9),
#  ('merit', 9),
#  ('soul', 9),
#  ('friendli', 9),
#  ('otherwis', 9),
#  ('maid', 9),
#  ('mamma', 9),
#  ('anywher', 9),
#  ('necess', 9),
#  ('thirti', 9),
#  ('forgotten', 9),
#  ('ascertain', 9),
#  ('aunt', 9),
#  ('quietli', 9),
#  ('ah', 9),
#  ('pray', 9),
#  ('tire', 9),
#  ('mistaken', 9),
#  ('declin', 9),
#  ('spot', 9),
#  ('restor', 9),
#  ('news', 9),
#  ('pretend', 9),
#  ('persuas', 8),
#  ...]

# %%
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for m in modals:
    print(m + ':', persuationFdist[m])
    
print(" ")
# Out:
# can: 107
# could: 451
# may: 87
# might: 166
# must: 228
# will: 172

# %%
pronouns = ['he', 'him', 'himself', 'she', 'her', 'herself']

for p in pronouns:
    print(p + ':', persuationFdist[p])
# Out:
# he: 961
# him: 467
# himself: 95
# she: 1146
# her: 1215
# herself: 159

# %%
moby = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
cleanedMoby=preprocess_data(moby)
mobyStem=stem(cleanedMoby,'porter')
mobyFdist = nltk.FreqDist(mobyStem)
print(mobyFdist.most_common())
# Out:
# [('the', 14431), ('of', 6613), ('and', 6437), ('a', 4736), ('to', 4628), ('in', 4172), ('that', 3085), ('it', 2898), ('hi', 2530), ('i', 2127), ('he', 1896), ('but', 1818), ('s', 1802), ('as', 1741), ('is', 1725), ('with', 1722), ('wa', 1645), ('whale', 1626), ('for', 1617), ('all', 1526), ('thi', 1507), ('at', 1319), ('be', 1279), ('by', 1204), ('not', 1151), ('from', 1088), ('him', 1067), ('so', 1065), ('on', 1062), ('one', 941), ('you', 894), ('there', 869), ('have', 834), ('now', 785), ('had', 779), ('or', 713), ('were', 684), ('they', 667), ('like', 661), ('which', 648), ('their', 633), ('me', 633), ('then', 630), ('ship', 623), ('what', 618), ('some', 618), ('when', 606), ('are', 598), ('an', 596), ('my', 589), ('no', 586), ('upon', 566), ('out', 551), ('ye', 547), ('sea', 542), ('man', 541), ('into', 523), ('up', 521), ('ahab', 512), ('more', 508), ('boat', 483), ('if', 482), ('them', 474), ('head', 466), ('seem', 463), ('we', 460), ('other', 455), ('old', 450), ('time', 449), ('would', 432), ('been', 415), ('over', 409), ('these', 403), ('will', 398), ('though', 384), ('down', 378), ('onli', 376), ('such', 370), ('hand', 367), ('look', 366), ('who', 363), ('captain', 353), ('yet', 345), ('long', 339), ('her', 338), ('ha', 330), ('say', 330), ('ani', 327), ('here', 325), ('veri', 322), ('do', 322), ('thing', 320), ('still', 315), ('see', 313), ('white', 311), ('about', 310), ('than', 309), ('great', 308), ('those', 306), ('said', 304), ('two', 301), ('befor', 299), ('t', 291), ('way', 291), ('come', 287), ('must', 283), ('go', 283), ('most', 282), ('last', 281), ('eye', 280), ('thou', 271), ('after', 270), ('again', 264), ('round', 260), ('water', 260), ('stubb', 260), ('your', 258), ('day', 258), ('did', 258), ('how', 256), ('harpoon', 256), ('queequeg', 252), ('littl', 249), ('three', 248), ('while', 246), ('men', 244), ('sperm', 244), ('may', 240), ('side', 239), ('can', 236), ('first', 235), ('through', 233), ('everi', 232), ('well', 231), ('us', 228), ('much', 223), ('good', 222), ('off', 220), ('sail', 220), ('where', 220), ('stand', 218), ('deck', 217), ('could', 216), ('take', 215), ('turn', 215), ('same', 214), ('cri', 214), ('own', 213), ('our', 211), ('even', 209), ('ever', 206), ('never', 206), ('himself', 205), ('part', 200), ('make', 198), ('line', 198), ('starbuck', 198), ('call', 196), ('know', 196), ('almost', 195), ('back', 190), ('thought', 188), ('too', 185), ('world', 183), ('might', 183), ('should', 183), ('away', 183), ('live', 182), ('chapter', 181), ('god', 180), ('place', 180), ('made', 178), ('fish', 177), ('sir', 176), ('life', 174), ('pequod', 173), ('think', 172), ('sort', 171), ('among', 167), ('mani', 166), ('seen', 165), ('far', 165), ('let', 162), ('tell', 162), ('night', 161), ('right', 159), ('crew', 157), ('mast', 156), ('without', 156), ('oh', 156), ('nor', 156), ('aye', 155), ('onc', 149), ('don', 144), ('air', 143), ('hold', 142), ('arm', 141), ('whole', 137), ('half', 136), ('against', 134), ('point', 134), ('thu', 133), ('sailor', 133), ('heart', 132), ('give', 132), ('thee', 131), ('voyag', 131), ('came', 130), ('soon', 130), ('strang', 130), ('present', 130), ('small', 129), ('nantucket', 128), ('each', 128), ('leg', 128), ('feet', 127), ('end', 126), ('get', 125), ('both', 124), ('full', 123), ('year', 123), ('someth', 123), ('leviathan', 122), ('till', 122), ('moment', 121), ('sight', 121), ('bodi', 120), ('found', 120), ('she', 120), ('under', 120), ('between', 120), ('face', 120), ('work', 119), ('saw', 119), ('mate', 119), ('whi', 119), ('gener', 118), ('just', 117), ('noth', 115), ('anoth', 115), ('poor', 114), ('toward', 114), ('ll', 114), ('roll', 111), ('bow', 111), ('high', 110), ('heard', 110), ('along', 110), ('flask', 109), ('run', 108), ('use', 108), ('feel', 107), ('light', 107), ('lower', 106), ('word', 105), ('soul', 105), ('mean', 105), ('black', 105), ('iron', 105), ('sun', 105), ('open', 102), ('land', 101), ('spout', 101), ('mind', 101), ('bone', 100), ('m ...

# %%
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for m in modals:
    print(m + ':', mobyFdist[m])
    
print(" ")

pronouns = ['he', 'him', 'himself', 'she', 'her', 'herself']

for p in pronouns:
    print(p + ':', mobyFdist[p])
# Out:
# can: 236
# could: 216
# may: 240
# might: 183
# must: 283
# will: 398
#
# he: 1896
# him: 1067
# himself: 205
# she: 120
# her: 338
# herself: 7

# %% [markdown]
# Here we got the lenght of the both corpora as, Austen's corpora has 84121 words after stemming and Moby Dick has 218361 words after stemming.
#
# As we can see the verb frequency distribution of Austen's corpora are lesser than the Moby Dick corpora, but here we also have to conside the lenght of the corpora.
#
# Also as we can see the pronoun frequency distribution for Austen's corpora has larger counts for 'her, herself, she' than Moby Dick's corpora. So we can refer Austen's corpora as a female oriented text.
#
# On the other hand, the frequency distributon for Moby Dick's corpora has larger counts for 'he, himself, him' than Austen's corpora. So we can refer Moby Dick's corpora as a male oriented text.

# %%
merged=[]
for w in persuationStem:
    merged.append(('persuation',w))

# %%
for w in mobyStem:
    merged.append(('moby',w))

# %%
auths=['persuation','moby']
modals = ['can', 'could', 'may', 'might', 'must', 'will']

# %%
merged[:10]
# Out:
# [('persuation', 'persuas'),
#  ('persuation', 'by'),
#  ('persuation', 'jane'),
#  ('persuation', 'austen'),
#  ('persuation', 'chapter'),
#  ('persuation', 'sir'),
#  ('persuation', 'walter'),
#  ('persuation', 'elliot'),
#  ('persuation', 'of'),
#  ('persuation', 'kellynch')]

# %%
cfd = nltk.ConditionalFreqDist(
           (genre, word)
           for genre in auths
           for k,word in merged
           if k == genre)
cfd.tabulate(conditions=auths, samples=modals)
# Out:
#              can could   may might  must  will
# persuation   107   451    87   166   228   172
#       moby   236   216   240   183   283   398
